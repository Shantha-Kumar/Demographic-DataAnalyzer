# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('adult.data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
pd.isna(None)
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# How many people of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.

# %%
df2=df['race'].value_counts()

# %% [markdown]
# What is the average age of men?

# %%
df['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
df3=df[df['sex']=='Male']
df3['age'].mean()
# Out:
# 39.43354749885268

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# What is the percentage of people who have a Bachelor's degree?

# %%
df4=df[df['education']=='Bachelors']
a=df4['education'].value_counts()
b=df['education'].value_counts()

# %%
b=b.sum()

# %%
b
# Out:
# 32561

# %%
cen=(a/b)*100

# %%
cen
# Out:
# Bachelors    16.446055
# Name: education, dtype: float64

# %% [markdown]
# What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

# %%
df5=df[(df['education']=='Bachelors') | (df['education']=='Masters')|(df['education']=='Doctorate') ]

# %%
df6=df5[df5['salary']=='>50K']

# %%
df6
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 8       31           Private   45781    Masters             14
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# 19      43  Self-emp-not-inc  292175    Masters             14
# 20      40           Private  193524  Doctorate             16
# ...    ...               ...     ...        ...            ...
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# ...

# %%
f=df6['salary'].value_counts()
g=df5['salary'].value_counts()

# %%
g=g.sum()

# %%
g
# Out:
# 7491

# %%
cen1=(f/g)*100

# %%
cen1
# Out:
# >50K    46.535843
# Name: salary, dtype: float64

# %%
df['hours-per-week'].min()
# Out:
# 1

# %% [markdown]
# What percentage of people without advanced education make more than 50K?

# %%
df7=df[(df['education']!='Bachelors') & (df['education']!='Masters')&(df['education']!='Doctorate') ]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25070 entries, 2 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25070 non-null  int64
#  1   workclass       25070 non-null  object
#  2   fnlwgt          25070 non-null  int64
#  3   education       25070 non-null  object
#  4   education-num   25070 non-null  int64
#  5   marital-status  25070 non-null  object
#  6   occupation      25070 non-null  object
#  7   relationship    25070 non-null  object
#  8   race            25070 non-null  object
#  9   sex             25070 non-null  object
#  10  capital-gain    25070 non-null  int64
#  11  capital-loss    25070 non-null  int64
#  12  hours-per-week  25070 non-null  int64
#  13  native-country  25070 non-null  object
#  14  salary          25070 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.1+ MB

# %%
iop=df7['education'].value_counts()
iop=iop.sum()

# %%
dfp=df7[df7['salary']=='>50K']

# %%
l=dfp['salary'].value_counts()

# %%
l
# Out:
# >50K    4355
# Name: salary, dtype: int64

# %%
cen3=(l/iop)*100

# %%
cen3
# Out:
# >50K    17.37136
# Name: salary, dtype: float64

# %% [markdown]
# What is the minimum number of hours a person works per week?

# %%
df8=df[(df['hours-per-week']==1)&(df['salary']=='>50K')]

# %% [markdown]
# What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
x=len(df8.index)

df78=df[df['hours-per-week']==1]

# %%
gh=df78['hours-per-week'].value_counts()

# %%
cen5=(x/gh)*100
cen5
# Out:
# 1    10.0
# Name: hours-per-week, dtype: float64

# %% [markdown]
# What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
op=df[df['native-country']=='India']

# %%
op=op[op['salary']=='>50K']

# %%
op
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 11      30         State-gov  141297    Bachelors             13
# 968     48           Private  164966    Bachelors             13
# 1327    52           Private  168381      HS-grad              9
# 7258    42         State-gov  102343  Prof-school             15
# 7285    54         State-gov   93449      Masters             14
# 8124    36           Private  172104  Prof-school             15
# 9939    43       Federal-gov  325706  Prof-school             15
# 10590   35           Private   98283  Prof-school             15
# 10661   59           Private  122283  Prof-school             15
# 10736   30           Private  243190  Prof-school             15
# 11260   54           Private  225599      Masters             14
# 11384   34           Private   98283  Prof-school             15
# 13422   53           Private  366957    Bachelors             13
# ...

# %%
po=op['occupation'].describe()
po
# Out:
# count                 40
# unique                 7
# top       Prof-specialty
# freq                  25
# Name: occupation, dtype: object

# %%
po1=po['top']
print(po1)
# Out:
# Prof-specialty

# %%
b=df[df['native-country']=='Iran']

# %%
b['native-country'].value_counts()
# Out:
# Iran    43
# Name: native-country, dtype: int64

# %%
highest_country = (
        df[["salary", "native-country"]]
        .groupby("native-country")
        .apply(lambda go: go.loc[go["salary"] == ">50K"].size / go.size * 100)
    )

# %%
highest_country
# Out:
# native-country
# ?                             25.042882
# Cambodia                      36.842105
# Canada                        32.231405
# China                         26.666667
# Columbia                       3.389831
# Cuba                          26.315789
# Dominican-Republic             2.857143
# Ecuador                       14.285714
# El-Salvador                    8.490566
# England                       33.333333
# France                        41.379310
# Germany                       32.116788
# Greece                        27.586207
# Guatemala                      4.687500
# Haiti                          9.090909
# Holand-Netherlands             0.000000
# Honduras                       7.692308
# Hong                          30.000000
# Hungary                       23.076923
# India                         40.000000
# Iran                          41.860465
# Ireland                       20.833333
# Italy                         34.246575
# ...

# %%
highest_earning_country = highest_country.idxmax()
highest_earning_country
highest_earning_country_percentage = round(highest_country.max(), 1)
highest_earning_country_percentage
# Out:
# 41.9

# %%
print(highest_earning_country)
# Out:
# Iran

# %%
a=df[["salary", "native-country"]].groupby("native-country")

# %%
type(a)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy
